# %%
from backcountry_mtn_us import backcountry_mtn_us as bm

# %%
bm.state_station(state = "NM")
# Out:
#      elevation                 name  timezone       triplet   wind  \
# 16        9050    NAVAJO WHISKEY CK        -7  1138:NM:SNTL  False
# 41       10000             HOPEWELL        -7   532:NM:SNTL   True
# 59        8360          SIGNAL PEAK        -7   755:NM:SNTL  False
# 109       9800        GALLEGOS PEAK        -7   491:NM:SNTL   True
# 183      10280        SIERRA BLANCA        -7  1034:NM:SNTL   True
# 199      11445             SANTA FE        -7   922:NM:SNTL   True
# 212      10600       NORTH COSTILLA        -7   665:NM:SNTL   True
# 246       8600           TRES RITOS        -7  1083:NM:SNTL   True
# 301       8400              CHAMITA        -7   394:NM:SNTL   True
# 359       9300              BATEMAN        -7   316:NM:SNTL   True
# 421       9850    RED RIVER PASS #2        -7   715:NM:SNTL   True
# 465      10180                TOLBY        -7   934:NM:SNTL  False
# 470       9000  SILVER CREEK DIVIDE        -7   757:NM:SNTL   True
# ...
